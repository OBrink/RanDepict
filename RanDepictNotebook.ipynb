# %%
import ipyplot
from RanDepict import random_depictor

# %% [markdown]
# ## Depict chemical structures with CDK, RDKit or Indigo
#
# After calling an instance of random_depictor, depictions with randomly chosen parameters are created by calling the functions
# - depict_and_resize_cdk(
#       smiles: str,
#       image_shape: Tuple[int,int]
#   )
# - depict_and_resize_rdkit(
#       smiles: str,
#       image_shape: Tuple[int,int]
#   )
# - depict_and_resize_indigo(
#       smiles: str,
#       image_shape: Tuple[int,int]
#   )
#
#
# The SMILES string needs to be given, the image_shape defaults to (299,299,3).
#
# Each of these functions returns an np.array which represents an RGB image of the chemical structure.

# %%
smiles = "CN1C=NC2=C1C(=O)N(C(=O)N2C)C"
depiction_img_shape = (299,299)


with random_depictor() as depictor:
    # CDK depictions
    cdk_images = []
    for _ in range(10):
        cdk_images.append(depictor. depict_and_resize_cdk(smiles, depiction_img_shape))
    print("_________________", "CDK depictions", "_________________")
    ipyplot.plot_images(cdk_images, max_images=10, img_width=299)
    
    # RDKit Depictions
    rdkit_images = []
    for _ in range(10):
        rdkit_images.append(depictor.depict_and_resize_rdkit(smiles, depiction_img_shape))
    print("_________________", "RDKit depictions", "_________________")
    ipyplot.plot_images(rdkit_images, max_images=10, img_width=299)
    
    # Indigo Depictions
    indigo_images = []
    for _ in range(10):
        indigo_images.append(depictor.depict_and_resize_indigo(smiles, depiction_img_shape))
    print("_________________", "Indigo depictions", "_________________")
    ipyplot.plot_images(indigo_images, max_images=10, img_width=299)
# Out:
# _________________ CDK depictions _________________
#     <style>
#         #ipyplot-html-viewer-toggle-K6WnqQLdgJXd7Do4s5AZRg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-K6WnqQLdgJXd7Do4s5AZRg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-K6WnqQLdgJXd7Do4s5AZRg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-K6WnqQLdgJXd7Do4s5AZRg:checked ~ #ipyplot-html-viewer-textarea-K6WnqQLdgJXd7Do4s5AZRg {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-K6WnqQLdgJXd7Do4s5AZRg:checked + #ipyplot-html-viewer-label-K6WnqQLdgJXd7Do4s5AZRg:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-K6WnqQLdgJXd7Do4s5AZRg">
#         <label id="ipyplot-html-viewer-label-K6WnqQLdgJXd7Do4s5AZRg" for="ipyplot-html-viewer-toggle-K6WnqQLdgJXd7Do4s5AZRg">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-K6WnqQLdgJXd7Do4s5AZRg" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mKjRG5WxwzEG85ubEhf8zw">
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-JbwNEevkNcUopfmQNLK5fj" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-JbwNEevkNcUopfmQNLK5fj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-FipDggGTXyxyBRh9cyYYcL" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-FipDggGTXyxyBRh9cyYYcL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-hKZTkWPKdWD6jtkAKQMGM7" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-hKZTkWPKdWD6jtkAKQMGM7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-7kvBktw4T42AE9ssqttg7W" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-7kvBktw4T42AE9ssqttg7W">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-47xp9tswVn27wN87dbus9U" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-47xp9tswVn27wN87dbus9U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-2zAH8UFsYxfK3uUA9Bd4hR" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-2zAH8UFsYxfK3uUA9Bd4hR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-MGVG6ZU7RTYzsu8SgNrSG9" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-MGVG6ZU7RTYzsu8SgNrSG9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-XfSdVez4i4pMSrEK26cas
#         <style>
#         #ipyplot-imgs-container-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mKjRG5WxwzEG85ubEhf8zw">
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-JbwNEevkNcUopfmQNLK5fj" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-JbwNEevkNcUopfmQNLK5fj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-FipDggGTXyxyBRh9cyYYcL" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-FipDggGTXyxyBRh9cyYYcL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-hKZTkWPKdWD6jtkAKQMGM7" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-hKZTkWPKdWD6jtkAKQMGM7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-7kvBktw4T42AE9ssqttg7W" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-7kvBktw4T42AE9ssqttg7W">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-47xp9tswVn27wN87dbus9U" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-47xp9tswVn27wN87dbus9U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-2zAH8UFsYxfK3uUA9Bd4hR" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-2zAH8UFsYxfK3uUA9Bd4hR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-MGVG6ZU7RTYzsu8SgNrSG9" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-MGVG6ZU7RTYzsu8SgNrSG9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-XfSdVez4i4pMSrEK26casV" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-XfSdVez4i4pMSrEK26casV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-L8RjxdV3rtWnKnCwn8V9UR" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-L8RjxdV3rtWnKnCwn8V9UR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mKjRG5WxwzEG85ubEhf8zw">
#         <div id="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-ZA5bW6TofaM8qNeR4B9F4D" class="ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mKjRG5WxwzEG85ubEhf8zw-ZA5bW6TofaM8qNeR4B9F4D">
# _________________ RDKit depictions _________________
#     <style>
#         #ipyplot-html-viewer-toggle-SgfxTL4eF2vEpSuntb76mh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SgfxTL4eF2vEpSuntb76mh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SgfxTL4eF2vEpSuntb76mh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SgfxTL4eF2vEpSuntb76mh:checked ~ #ipyplot-html-viewer-textarea-SgfxTL4eF2vEpSuntb76mh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SgfxTL4eF2vEpSuntb76mh:checked + #ipyplot-html-viewer-label-SgfxTL4eF2vEpSuntb76mh:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-SgfxTL4eF2vEpSuntb76mh">
#         <label id="ipyplot-html-viewer-label-SgfxTL4eF2vEpSuntb76mh" for="ipyplot-html-viewer-toggle-SgfxTL4eF2vEpSuntb76mh">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-SgfxTL4eF2vEpSuntb76mh" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EzbSb5bVN75YpHsQko5qZV">
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-krU3DRpDYiQ3uAfgVvHcbE" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-krU3DRpDYiQ3uAfgVvHcbE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-Fsvvb4dshocxn8UHhwgcmL" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-Fsvvb4dshocxn8UHhwgcmL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-V43oXMkHkvF2BWKu6zxtnk" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-V43oXMkHkvF2BWKu6zxtnk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-FwZeH9XLtxWS2z9A8L2Yit" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-FwZeH9XLtxWS2z9A8L2Yit">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-U2mJJiS7PCmpq5KYStC9mj" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-U2mJJiS7PCmpq5KYStC9mj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-9f9ryMWNMjPPUABEoZc6du" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-9f9ryMWNMjPPUABEoZc6du">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-UVdxVq9s2MiisjLUPYqsPG" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-UVdxVq9s2MiisjLUPYqsPG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-cAiWSFn4W44Dyc5YaFuxS
#         <style>
#         #ipyplot-imgs-container-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EzbSb5bVN75YpHsQko5qZV">
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-krU3DRpDYiQ3uAfgVvHcbE" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-krU3DRpDYiQ3uAfgVvHcbE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-Fsvvb4dshocxn8UHhwgcmL" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-Fsvvb4dshocxn8UHhwgcmL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-V43oXMkHkvF2BWKu6zxtnk" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-V43oXMkHkvF2BWKu6zxtnk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-FwZeH9XLtxWS2z9A8L2Yit" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-FwZeH9XLtxWS2z9A8L2Yit">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-U2mJJiS7PCmpq5KYStC9mj" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-U2mJJiS7PCmpq5KYStC9mj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-9f9ryMWNMjPPUABEoZc6du" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-9f9ryMWNMjPPUABEoZc6du">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-UVdxVq9s2MiisjLUPYqsPG" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-UVdxVq9s2MiisjLUPYqsPG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-cAiWSFn4W44Dyc5YaFuxSn" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-cAiWSFn4W44Dyc5YaFuxSn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-G6WAiKDdF4hspQYshGtfTL" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-G6WAiKDdF4hspQYshGtfTL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EzbSb5bVN75YpHsQko5qZV">
#         <div id="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-NX3cuHNY7CfAZDWnTxEHYv" class="ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EzbSb5bVN75YpHsQko5qZV-NX3cuHNY7CfAZDWnTxEHYv">
# _________________ Indigo depictions _________________
#     <style>
#         #ipyplot-html-viewer-toggle-5KUeNVVJUYVKWFwZGTCP4L {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5KUeNVVJUYVKWFwZGTCP4L {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5KUeNVVJUYVKWFwZGTCP4L {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5KUeNVVJUYVKWFwZGTCP4L:checked ~ #ipyplot-html-viewer-textarea-5KUeNVVJUYVKWFwZGTCP4L {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5KUeNVVJUYVKWFwZGTCP4L:checked + #ipyplot-html-viewer-label-5KUeNVVJUYVKWFwZGTCP4L:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-5KUeNVVJUYVKWFwZGTCP4L">
#         <label id="ipyplot-html-viewer-label-5KUeNVVJUYVKWFwZGTCP4L" for="ipyplot-html-viewer-toggle-5KUeNVVJUYVKWFwZGTCP4L">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-5KUeNVVJUYVKWFwZGTCP4L" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-cjrebZHwc562GVn72SBUEs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cjrebZHwc562GVn72SBUEs">
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-gswVxdS4NBSJEDcXJWQrnW" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-gswVxdS4NBSJEDcXJWQrnW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-JUtXh57jHnom4ZH2JmjAwy" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-JUtXh57jHnom4ZH2JmjAwy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-iabLRFZ2tnxc7ayyRtDyjL" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-iabLRFZ2tnxc7ayyRtDyjL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-g3iBiceL4mbrrEGdQaPedW" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-g3iBiceL4mbrrEGdQaPedW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-MyyJJ6Vkfuapruzrj3iQDn" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-MyyJJ6Vkfuapruzrj3iQDn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-PuTacWGrQmh7bWj4A333go" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-PuTacWGrQmh7bWj4A333go">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-crJhmnTAQrR36RCS3kCrms" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-crJhmnTAQrR36RCS3kCrms">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-dFtpsgNdS8RvMC9Smaag5
#         <style>
#         #ipyplot-imgs-container-div-cjrebZHwc562GVn72SBUEs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cjrebZHwc562GVn72SBUEs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cjrebZHwc562GVn72SBUEs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cjrebZHwc562GVn72SBUEs">
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-gswVxdS4NBSJEDcXJWQrnW" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-gswVxdS4NBSJEDcXJWQrnW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-JUtXh57jHnom4ZH2JmjAwy" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-JUtXh57jHnom4ZH2JmjAwy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-iabLRFZ2tnxc7ayyRtDyjL" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-iabLRFZ2tnxc7ayyRtDyjL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-g3iBiceL4mbrrEGdQaPedW" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-g3iBiceL4mbrrEGdQaPedW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-MyyJJ6Vkfuapruzrj3iQDn" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-MyyJJ6Vkfuapruzrj3iQDn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-PuTacWGrQmh7bWj4A333go" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-PuTacWGrQmh7bWj4A333go">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-crJhmnTAQrR36RCS3kCrms" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-crJhmnTAQrR36RCS3kCrms">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-dFtpsgNdS8RvMC9Smaag59" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-dFtpsgNdS8RvMC9Smaag59">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-mDBrGQ6C9fjy7nuvCnMBtf" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-mDBrGQ6C9fjy7nuvCnMBtf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cjrebZHwc562GVn72SBUEs">
#         <div id="ipyplot-content-div-cjrebZHwc562GVn72SBUEs-io5KKFxCUWY5f38YWpdc8Z" class="ipyplot-content-div-cjrebZHwc562GVn72SBUEs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cjrebZHwc562GVn72SBUEs-io5KKFxCUWY5f38YWpdc8Z">

# %% [markdown]
# ## Depict chemical structures with a random toolkit
#
# After calling an instance of random_depictor, the function
#  - random_depiction(
#        smiles: str,
#        image_shape: Tuple[int,int]
#    )
#
# The SMILES string needs to be given, the image_shape defaults to (299,299).
#
# It returns an np.array which represents an RGB image of the chemical structure.

# %%
with random_depictor() as depictor:
    random_images = []
    for _ in range(20):
        random_images.append(depictor.random_depiction(smiles))

ipyplot.plot_images(random_images, max_images=20, img_width=299)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-SXGWEKoN6g8uzG3rmYSzuk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SXGWEKoN6g8uzG3rmYSzuk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SXGWEKoN6g8uzG3rmYSzuk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SXGWEKoN6g8uzG3rmYSzuk:checked ~ #ipyplot-html-viewer-textarea-SXGWEKoN6g8uzG3rmYSzuk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SXGWEKoN6g8uzG3rmYSzuk:checked + #ipyplot-html-viewer-label-SXGWEKoN6g8uzG3rmYSzuk:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-SXGWEKoN6g8uzG3rmYSzuk">
#         <label id="ipyplot-html-viewer-label-SXGWEKoN6g8uzG3rmYSzuk" for="ipyplot-html-viewer-toggle-SXGWEKoN6g8uzG3rmYSzuk">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-SXGWEKoN6g8uzG3rmYSzuk" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FNxtDKjuUioMYWqqQJYTx8">
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-nWNhAXTxsFodznzyC5Vwvi" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-nWNhAXTxsFodznzyC5Vwvi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-KKZcNHmpXq9rCUU8yqk8CP" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-KKZcNHmpXq9rCUU8yqk8CP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-aJjVp3u6jNTHiogSmFP4H5" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-aJjVp3u6jNTHiogSmFP4H5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GCT2a8axAcSsicieUruoVH" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GCT2a8axAcSsicieUruoVH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GAFWyb5BAZhsn7utLnSHzT" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GAFWyb5BAZhsn7utLnSHzT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-93VpMBRanKqyKy8HYXiufH" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-93VpMBRanKqyKy8HYXiufH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-8U34jja5YKf52LEt7GFwKb" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-8U34jja5YKf52LEt7GFwKb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-e4ZA6L6UYKY339Efu8Eau
#         <style>
#         #ipyplot-imgs-container-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FNxtDKjuUioMYWqqQJYTx8">
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-nWNhAXTxsFodznzyC5Vwvi" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-nWNhAXTxsFodznzyC5Vwvi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-KKZcNHmpXq9rCUU8yqk8CP" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-KKZcNHmpXq9rCUU8yqk8CP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-aJjVp3u6jNTHiogSmFP4H5" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-aJjVp3u6jNTHiogSmFP4H5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GCT2a8axAcSsicieUruoVH" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GCT2a8axAcSsicieUruoVH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GAFWyb5BAZhsn7utLnSHzT" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-GAFWyb5BAZhsn7utLnSHzT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-93VpMBRanKqyKy8HYXiufH" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-93VpMBRanKqyKy8HYXiufH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-8U34jja5YKf52LEt7GFwKb" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-8U34jja5YKf52LEt7GFwKb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-e4ZA6L6UYKY339Efu8EauQ" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-e4ZA6L6UYKY339Efu8EauQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-gnoLB26MQiBngxtFSpS29q" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-gnoLB26MQiBngxtFSpS29q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FNxtDKjuUioMYWqqQJYTx8">
#         <div id="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-FysEysbjAkA7Mgcoh7MAD7" class="ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FNxtDKjuUioMYWqqQJYTx8-FysEysbjAkA7Mgcoh7MAD7">

# %% [markdown]
# ## Create random depictions with random augmentations
#
# After calling an instance of random_depictor, this instance can simply be called as a function in order to generate a chemical structure depiction using CDK, RDKit or Indigo (randomly chosen) and apply random augmentations. The augmentations consist of random imgaug augmentations and randomly added chemical ID labels or curved arrows

# %%
with random_depictor() as depictor:
    random_augmented_images = []
    for _ in range(20):
        random_augmented_images.append(depictor(smiles))

ipyplot.plot_images(random_augmented_images, max_images=20, img_width=299)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hYVSSDDXNskeTkLteS78XX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hYVSSDDXNskeTkLteS78XX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hYVSSDDXNskeTkLteS78XX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hYVSSDDXNskeTkLteS78XX:checked ~ #ipyplot-html-viewer-textarea-hYVSSDDXNskeTkLteS78XX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hYVSSDDXNskeTkLteS78XX:checked + #ipyplot-html-viewer-label-hYVSSDDXNskeTkLteS78XX:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-hYVSSDDXNskeTkLteS78XX">
#         <label id="ipyplot-html-viewer-label-hYVSSDDXNskeTkLteS78XX" for="ipyplot-html-viewer-toggle-hYVSSDDXNskeTkLteS78XX">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-hYVSSDDXNskeTkLteS78XX" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5jhNwSFzQpZuHcPeDPzw43">
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-SzkZeAynjqbB6FC9J3Ux5S" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-SzkZeAynjqbB6FC9J3Ux5S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-BthApdJLdamLAUmJ5b2mfy" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-BthApdJLdamLAUmJ5b2mfy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-M8WnersYGJ2EopJ37uLKdW" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-M8WnersYGJ2EopJ37uLKdW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-GvdKdezatkhBErnocQv8NA" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-GvdKdezatkhBErnocQv8NA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4k9xqdKa3DrL4tbBSXbgDo" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4k9xqdKa3DrL4tbBSXbgDo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-5Th83cZ6yfBYvMgE2egmyS" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-5Th83cZ6yfBYvMgE2egmyS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-jiCickfRBNikYYsMqGv69P" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-jiCickfRBNikYYsMqGv69P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-ZYRGX6E7Ympu9VDtcmQJ5
#         <style>
#         #ipyplot-imgs-container-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 299px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 {
#             width: 299px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 img {
#             width: 299px;
#         }
#
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5jhNwSFzQpZuHcPeDPzw43">
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-SzkZeAynjqbB6FC9J3Ux5S" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-SzkZeAynjqbB6FC9J3Ux5S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-BthApdJLdamLAUmJ5b2mfy" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-BthApdJLdamLAUmJ5b2mfy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-M8WnersYGJ2EopJ37uLKdW" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-M8WnersYGJ2EopJ37uLKdW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-GvdKdezatkhBErnocQv8NA" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-GvdKdezatkhBErnocQv8NA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4k9xqdKa3DrL4tbBSXbgDo" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4k9xqdKa3DrL4tbBSXbgDo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-5Th83cZ6yfBYvMgE2egmyS" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-5Th83cZ6yfBYvMgE2egmyS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-jiCickfRBNikYYsMqGv69P" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-jiCickfRBNikYYsMqGv69P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-ZYRGX6E7Ympu9VDtcmQJ5n" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-ZYRGX6E7Ympu9VDtcmQJ5n">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-gobkEhwWm2HYMiDNSqNrwT" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-gobkEhwWm2HYMiDNSqNrwT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5jhNwSFzQpZuHcPeDPzw43">
#         <div id="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4nkkCKDDSFqmp5366C35g2" class="ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5jhNwSFzQpZuHcPeDPzw43-4nkkCKDDSFqmp5366C35g2">

# %% [markdown]
# ##

# %% [markdown]
# ## Create and save a batch of images
#
# After calling an instance of random_depictor, simply call the functions
#
#  - batch_depict_save(
#         self,
#         smiles_list: List[str],
#         images_per_structure: int,
#         output_dir: str,
#         shape: Tuple[int, int] = (299, 299),
#         ID_list = False,
#     )
#  - def batch_depict_augment_save(
#         self,
#         smiles_list: List[str],
#         images_per_structure: int,
#         output_dir: str,
#         shape: Tuple[int, int] = (299, 299),
#         ID_list = False,
#     )
#
# with a list of SMILES, the amount of images to create per SMILES, an output directory path and the desired size of the output images. If desired, a list of IDs of the same length as smiles_list give the created images specific file names.

# %%
if not os.path.exists('not_augmented'):
        os.mkdir('not_augmented')
        
if not os.path.exists('augmented'):
        os.mkdir('augmented')
        
with random_depictor() as depictor:
    depictor.batch_depict_save([smiles], 5, 'not_augmented', (299, 299), ['caffeine'])
    depictor.batch_depict_augment_save([smiles], 5, 'augmented', (299, 299), ['caffeine'])
